# %% [markdown]
# # Computing features to train a MLP
# This notebook will guide you through the use of the `keras` package to train a multilayer perceptron for handwritten digits classification. You are going to computing the histogram of gradients from the images in the `mnist` dataset (LeCun et al. 1998)

# %% [markdown]
# ## Loading the packages

# %%
#%pip install tensorflow --upgrade
#%pip install keras --upgrade

import numpy as np
from matplotlib import pyplot as pl

from skimage.feature import hog
from skimage import data, color, exposure

from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

# %matplotlib inline

# %% [markdown]
# Load the `mnist` dataset and normalize in the range [0, 1]

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()

n_train, height, width = X_train.shape
n_test, _, _ = X_test.shape

X_train = X_train.reshape(n_train, height, width, 1).astype('float32')
X_test = X_test.reshape(n_test, height, width, 1).astype('float32')

X_train /= 255.0
X_test /= 255.0

n_classes = 10

print(n_train, 'train samples')
print(n_test, 'test samples')

# convert class vectors to binary class matrices
Y_train = to_categorical(y_train, n_classes)
Y_test = to_categorical(y_test, n_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ### An example of how to compute the histogram of gradients
# Let's compute the HOG for one image in the test dataset

# %%
n_orientations = 8
pix_p_cell = 4
hog_size = int(height * width * n_orientations / (pix_p_cell * pix_p_cell))

# %%
fd, hog_image = hog(X_test[0,:,:,0], orientations=n_orientations, pixels_per_cell=(pix_p_cell, pix_p_cell), cells_per_block=(1, 1), visualize=True)
hog_image_rescaled = exposure.rescale_intensity(hog_image, in_range=(0, 0.02))

# %% [markdown]
# Show the image and the corresponding gradients

# %%
fig, (ax1, ax2) = pl.subplots(1, 2, figsize=(12, 6), sharex=True, sharey=True)
ax1.axis('off')
ax1.imshow(X_test[0,:,:,0], cmap=pl.get_cmap('Greys'), interpolation='nearest')
ax1.set_title('Input image')
ax1.set_adjustable('box')

ax2.axis('off')
ax2.imshow(hog_image_rescaled, cmap=pl.get_cmap('Greys'), interpolation='nearest')
ax2.set_title('Histogram of Oriented Gradients')
ax1.set_adjustable('box')

# %% [markdown]
# Compute the HOGs for the train and test datasets

# %%
X_train_hog = np.zeros((X_train.shape[0], hog_size))
X_test_hog = np.zeros((X_test.shape[0], hog_size))

for i in np.arange(X_train_hog.shape[0]):
    X_train_hog[i,:] = hog(X_train[i,:,:,0], orientations=n_orientations, pixels_per_cell=(pix_p_cell, pix_p_cell), cells_per_block=(1, 1), visualize=False)
print('X_train done')

for i in np.arange(X_test_hog.shape[0]):
    X_test_hog[i,:] = hog(X_test[i,:,:,0], orientations=n_orientations, pixels_per_cell=(pix_p_cell, pix_p_cell), cells_per_block=(1, 1), visualize=False)
print('X_test done')
# Out:
# X_train done
# X_test done

# %% [markdown]
# Create the MLP

# %%
model = Sequential()
model.add(Input(shape=(hog_size,)))
model.add(Dense(2, activation='relu'))
#model.add(Dropout(0.5))
model.add(Dense(n_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 2)              │           786 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │            30 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 816 (3.19 KB)
#  Trainable params: 816 (3.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Define some constants and train the MLP

# %%
batch_size = 128
n_epoch = 50

model.compile(loss='categorical_crossentropy', optimizer=RMSprop(), metrics=['accuracy'])

history = model.fit(X_train_hog, Y_train,
                    batch_size=batch_size, epochs=n_epoch,
                    verbose=1, validation_split=0.1)
# Out:
# Epoch 1/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - accuracy: 0.1847 - loss: 2.0186 - val_accuracy: 0.3922 - val_loss: 1.5300
# Epoch 2/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.4213 - loss: 1.4848 - val_accuracy: 0.5255 - val_loss: 1.2843
# Epoch 3/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5332 - loss: 1.2882 - val_accuracy: 0.5980 - val_loss: 1.1438
# Epoch 4/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6036 - loss: 1.1555 - val_accuracy: 0.6583 - val_loss: 1.0460
# Epoch 5/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6364 - loss: 1.0693 - val_accuracy: 0.6668 - val_loss: 0.9786
# Epoch 6/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6503 - loss: 1.0076 - val_accuracy: 0.6742 - val_loss: 0.9343
# Epoch 7/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6654 - loss: 0.9681 - val_accuracy: 0.6908 - val_loss: 0.8993
# Epoch 8/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6770 - loss: 0.9320 - val_accuracy: 0.7027 - val_loss: 0.8717
# Epoch 9/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6901 - loss: 0.9096 - val_accuracy: 0.7173 - val_loss: 0.8501
# Epoch 10/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6992 - loss: 0.8940 - val_accuracy: 0.7263 - val_loss: 0.8314
# Epoch 11/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7085 - loss: 0.8710 - val_accuracy: 0.7335 - val_loss: 0.8153
# Epoch 12/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7178 - loss: 0.8447 - val_accuracy: 0.7428 - val_loss: 0.8041
# Epoch 13/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7245 - loss: 0.8423 - val_accuracy: 0.7538 - val_loss: 0.7881
# Epoch 14/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7344 - loss: 0.8283 - val_accuracy: 0.7575 - val_loss: 0.7756
# Epoch 15/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7378 - loss: 0.8091 - val_accuracy: 0.7637 - val_loss: 0.7644
# Epoch 16/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7493 - loss: 0.7974 - val_accuracy: 0.7680 - val_loss: 0.7516
# Epoch 17/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7457 - loss: 0.8045 - val_accuracy: 0.7688 - val_loss: 0.7451
# Epoch 18/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7514 - loss: 0.7915 - val_accuracy: 0.7702 - val_loss: 0.7349
# Epoch 19/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7549 - loss: 0.7769 - val_accuracy: 0.7715 - val_loss: 0.7259
# Epoch 20/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7580 - loss: 0.7722 - val_accuracy: 0.7732 - val_loss: 0.7217
# Epoch 21/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7597 - loss: 0.7646 - val_accuracy: 0.7750 - val_loss: 0.7154
# Epoch 22/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7618 - loss: 0.7584 - val_accuracy: 0.7782 - val_loss: 0.7106
# Epoch 23/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7653 - loss: 0.7530 - val_accuracy: 0.7782 - val_loss: 0.7076
# Epoch 24/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7652 - loss: 0.7472 - val_accuracy: 0.7830 - val_loss: 0.7013
# Epoch 25/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7640 - loss: 0.7407 - val_accuracy: 0.7812 - val_loss: 0.7002
# Epoch 26/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7638 - loss: 0.7427 - val_accuracy: 0.7820 - val_loss: 0.6946
# Epoch 27/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7642 - loss: 0.7481 - val_accuracy: 0.7843 - val_loss: 0.6935
# Epoch 28/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7681 - loss: 0.7396 - val_accuracy: 0.7838 - val_loss: 0.6904
# Epoch 29/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7708 - loss: 0.7301 - val_accuracy: 0.7852 - val_loss: 0.6873
# Epoch 30/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7686 - loss: 0.7315 - val_accuracy: 0.7852 - val_loss: 0.6880
# Epoch 31/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7676 - loss: 0.7269 - val_accuracy: 0.7865 - val_loss: 0.6825
# Epoch 32/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7726 - loss: 0.7165 - val_accuracy: 0.7860 - val_loss: 0.6813
# Epoch 33/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7725 - loss: 0.7231 - val_accuracy: 0.7877 - val_loss: 0.6778
# Epoch 34/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7736 - loss: 0.7200 - val_accuracy: 0.7887 - val_loss: 0.6756
# Epoch 35/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7758 - loss: 0.7117 - val_accuracy: 0.7893 - val_loss: 0.6746
# Epoch 36/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7755 - loss: 0.7171 - val_accuracy: 0.7903 - val_loss: 0.6716
# Epoch 37/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7726 - loss: 0.7176 - val_accuracy: 0.7888 - val_loss: 0.6711
# Epoch 38/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7714 - loss: 0.7219 - val_accuracy: 0.7917 - val_loss: 0.6699
# Epoch 39/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7737 - loss: 0.7106 - val_accuracy: 0.7898 - val_loss: 0.6673
# Epoch 40/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7756 - loss: 0.7183 - val_accuracy: 0.7927 - val_loss: 0.6646
# Epoch 41/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7748 - loss: 0.7101 - val_accuracy: 0.7927 - val_loss: 0.6633
# Epoch 42/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7764 - loss: 0.7075 - val_accuracy: 0.7922 - val_loss: 0.6628
# Epoch 43/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7775 - loss: 0.7082 - val_accuracy: 0.7963 - val_loss: 0.6613
# Epoch 44/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7787 - loss: 0.7055 - val_accuracy: 0.7938 - val_loss: 0.6593
# Epoch 45/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7746 - loss: 0.7182 - val_accuracy: 0.7925 - val_loss: 0.6609
# Epoch 46/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7800 - loss: 0.7002 - val_accuracy: 0.7928 - val_loss: 0.6588
# Epoch 47/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7777 - loss: 0.7035 - val_accuracy: 0.7935 - val_loss: 0.6573
# Epoch 48/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7746 - loss: 0.7135 - val_accuracy: 0.7950 - val_loss: 0.6565
# Epoch 49/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7774 - loss: 0.7082 - val_accuracy: 0.7918 - val_loss: 0.6585
# Epoch 50/50
# 422/422 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7774 - loss: 0.6981 - val_accuracy: 0.7965 - val_loss: 0.6525

# %% [markdown]
# Show the performance of the model

# %%
pl.plot(history.history['loss'], label='Training')
pl.plot(history.history['val_loss'], label='Testing')
pl.legend()
pl.grid()

score = model.evaluate(X_test_hog, Y_test, verbose=0)
print('Test score:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test score: 0.6719791293144226
# Test accuracy: 0.7886000275611877

# %% [markdown]
# Confusion matrix

# %%
pred = model.predict(X_test_hog)
pred = np.argmax(pred, axis=-1)
confusion_matrix(y_test, pred)

plt.figure(figsize=(10, 10))
sns.heatmap(confusion_matrix(y_test, pred), annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

f1_score_macro = f1_score(y_test, pred, average='macro')
f1_score_micro = f1_score(y_test, pred, average='micro')
f1_score_weighted = f1_score(y_test, pred, average='weighted')

print(f"F1 macro Score: {f1_score_macro}")
print(f"F1 weighted Score: {f1_score_weighted}")
print(f"F1 micro Score: {f1_score_micro}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# F1 macro Score: 0.7866239795537324
# F1 weighted Score: 0.7881170243483568
# F1 micro Score: 0.7886
