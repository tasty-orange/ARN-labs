# %% [markdown]
# <a href="https://colab.research.google.com/github/tasty-orange/ARN-labs/blob/main/ARN_PW3_COMPETITION_Piemontesi_Trueb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practical Work 3 ARN - G.Piemontesi & G.Trueb
#
# ## Compétition : Classification « awake », « n-rem » et « rem ».
#
# Même chose que l'expérience 2, mais cette fois-ci pour la compétition!

# %% [markdown]
# ### Import des packages/dépendances

# %%
# Importation des bibliothèques nécessaires
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Input, Dense
from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from collections import Counter
from sklearn.preprocessing import StandardScaler, LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from tensorflow.keras import regularizers
from tensorflow import keras
import tensorflow as tf
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score
from tensorflow.keras.layers import BatchNormalization
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix
from tensorflow import keras
from tensorflow.keras.models import load_model

# %% [markdown]
# ### Import des données des souris

# %%
# Chargement des données d'entraînement
mice_eeg_1 = pd.read_csv('EEG_mouse_data_1.csv')
mice_eeg_2 = pd.read_csv('EEG_mouse_data_2.csv')

# Fusion des deux jeux de données d'entraînement
data_training = pd.concat([mice_eeg_1, mice_eeg_2])

# %% [markdown]
# ###Preprocessing et normalisation des données

# %% [markdown]
# Comme on peut le voir dans le diagramme en barres ci-dessous, le sommeil des souris se divise en trois états : « awake », « NREM » et « REM ». Contrairement à l'approche binaire de la première expérience, nous conservons ici ces trois classes distinctes pour l'analyse.

# %%
# Visualisation de la distribution des états
plt.figure(figsize=(10, 6))
data_training.state.value_counts().plot(kind='bar', color='darkgreen')
plt.title('Total Occurences per State')
plt.xticks(rotation=0)
plt.ylabel('Count')
plt.xlabel('State')
plt.tight_layout()
plt.show()

# %%
# Séparer les caractéristiques et la variable cible
input_data = data_training.drop('state', axis=1).values
output_data = data_training['state'].values

# Garder seulement les 25 premières caractéristiques
input_data = input_data[:, :25]

# Normaliser les données d'entrée
scaler = StandardScaler()
input_data = scaler.fit_transform(input_data)

# Encoder la variable cible
# D'abord avec LabelEncoder pour obtenir des valeurs numériques
label_encoder = LabelEncoder()
output_labels = label_encoder.fit_transform(output_data)

# Puis appliquer l'encodage One-Hot
# Reshape les données de sortie pour appliquer OneHotEncoder
output_reshaped = output_labels.reshape(-1, 1)

# Appliquer l'encodage One-Hot
one_hot_encoder = OneHotEncoder(sparse_output=False)
output_data_onehot = one_hot_encoder.fit_transform(output_reshaped)

# Définir la validation croisée
kf = KFold(n_splits=5, shuffle=True, random_state=42)

# %% [markdown]
# ### Creation du modèle MLP

# %%
def create_model():
    model = Sequential([
        Input(shape=(25,)),

        # Première couche cachée
        Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        BatchNormalization(),
        Dropout(0.4),

        # Deuxième couche cachée
        Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        BatchNormalization(),
        Dropout(0.4),

        # Troisième couche cachée
        Dense(32, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        Dropout(0.3),

        # Couche de sortie pour 3 classes
        Dense(3, activation='softmax')
    ])

    # Compilation du modèle
    model.compile(
        loss='categorical_crossentropy',
        optimizer=keras.optimizers.Adam(learning_rate=0.001),
        metrics=['accuracy']
    )
    return model

# %% [markdown]
# ### Entraînement du modèle

# %%
accuracy_scores = []
best_accuracy = 0  # Variable pour suivre la meilleure précision
best_fold = -1  # Stocke l'indice du meilleur fold
best_model_path = "best_fold_model.h5"  # Fichier pour stocker le meilleur modèle

for fold, (train_index, test_index) in enumerate(kf.split(input_data)):
    X_train, X_test = input_data[train_index], input_data[test_index]
    y_train, y_test = output_data_onehot[train_index], output_data_onehot[test_index]

    # Création du modèle
    model = create_model()

    # Callbacks pour optimiser l'entraînement
    early_stopping = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-5)

    # Entraînement du modèle
    history = model.fit(
        X_train, y_train,
        epochs=50,
        batch_size=32,
        validation_data=(X_test, y_test),
        callbacks=[early_stopping, reduce_lr],
        verbose=1
    )

    # Évaluation du modèle
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
    accuracy_scores.append(accuracy)

    print(f"Fold {fold+1} - Accuracy : {accuracy:.4f}")

    # Sauvegarde du meilleur modèle
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_fold = fold + 1  # Fold commence à 0, donc on ajoute 1
        model.save(best_model_path)
        print(f"Meilleur modèle mis à jour (Fold {best_fold}, Accuracy: {best_accuracy:.4f})")

    # Affichage des courbes de perte
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Perte entraînement')
    plt.plot(history.history['val_loss'], label='Perte validation')
    plt.xlabel('Époque')
    plt.ylabel('Perte')
    plt.legend()
    plt.title(f'Courbe de perte (fold {fold+1})')
    plt.show()

    # Matrice de confusion
    cm = confusion_matrix(np.argmax(y_test, axis=1), np.argmax(y_pred, axis=1))
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Prédictions')
    plt.ylabel('Réelles')
    plt.title(f'Matrice de confusion (fold {fold+1})')
    plt.show()

# Affichage des performances globales
print(f"\nPrécision moyenne : {np.mean(accuracy_scores):.4f}")
print(f"Écart type de la précision : {np.std(accuracy_scores):.4f}")
print(f"Meilleur modèle sauvegardé : Fold {best_fold} avec une précision de {best_accuracy:.4f}")
# Out:
# Epoch 1/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 19s 11ms/step - accuracy: 0.7808 - loss: 0.7898 - val_accuracy: 0.8703 - val_loss: 0.4947 - learning_rate: 0.0010
# Epoch 2/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 14s 4ms/step - accuracy: 0.8529 - loss: 0.5363 - val_accuracy: 0.8750 - val_loss: 0.4461 - learning_rate: 0.0010
# Epoch 3/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8643 - loss: 0.4781 - val_accuracy: 0.8783 - val_loss: 0.4078 - learning_rate: 0.0010
# Epoch 4/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8666 - loss: 0.4424 - val_accuracy: 0.8769 - val_loss: 0.3868 - learning_rate: 0.0010
# Epoch 5/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8683 - loss: 0.4248 - val_accuracy: 0.8779 - val_loss: 0.3736 - learning_rate: 0.0010
# Epoch 6/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8696 - loss: 0.4046 - val_accuracy: 0.8808 - val_loss: 0.3682 - learning_rate: 0.0010
# Epoch 7/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8650 - loss: 0.4042 - val_accuracy: 0.8790 - val_loss: 0.3692 - learning_rate: 0.0010
# Epoch 8/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8698 - loss: 0.3945 - val_accuracy: 0.8806 - val_loss: 0.3651 - learning_rate: 0.0010
# Epoch 9/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8726 - loss: 0.3906 - val_accuracy: 0.8805 - val_loss: 0.3589 - learning_rate: 0.0010
# Epoch 10/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8664 - loss: 0.3956 - val_accuracy: 0.8802 - val_loss: 0.3627 - learning_rate: 0.0010
# Epoch 11/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8729 - loss: 0.3874 - val_accuracy: 0.8800 - val_loss: 0.3623 - learning_rate: 0.0010
# Epoch 12/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8707 - loss: 0.3885 - val_accuracy: 0.8816 - val_loss: 0.3591 - learning_rate: 0.0010
# Epoch 13/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8657 - loss: 0.3963 - val_accuracy: 0.8773 - val_loss: 0.3615 - learning_rate: 0.0010
# Epoch 14/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8716 - loss: 0.3881 - val_accuracy: 0.8827 - val_loss: 0.3557 - learning_rate: 0.0010
# Epoch 15/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8712 - loss: 0.3885 - val_accuracy: 0.8798 - val_loss: 0.3593 - learning_rate: 0.0010
# Epoch 16/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8689 - loss: 0.3892 - val_accuracy: 0.8802 - val_loss: 0.3579 - learning_rate: 0.0010
# Epoch 17/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8724 - loss: 0.3832 - val_accuracy: 0.8808 - val_loss: 0.3609 - learning_rate: 0.0010
# Epoch 18/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8726 - loss: 0.3843 - val_accuracy: 0.8787 - val_loss: 0.3603 - learning_rate: 0.0010
# Epoch 19/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8704 - loss: 0.3900 - val_accuracy: 0.8794 - val_loss: 0.3591 - learning_rate: 0.0010
# Epoch 20/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8741 - loss: 0.3820 - val_accuracy: 0.8823 - val_loss: 0.3509 - learning_rate: 5.0000e-04
# Epoch 21/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8720 - loss: 0.3820 - val_accuracy: 0.8812 - val_loss: 0.3495 - learning_rate: 5.0000e-04
# Epoch 22/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8727 - loss: 0.3775 - val_accuracy: 0.8809 - val_loss: 0.3488 - learning_rate: 5.0000e-04
# Epoch 23/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8744 - loss: 0.3749 - val_accuracy: 0.8806 - val_loss: 0.3481 - learning_rate: 5.0000e-04
# Epoch 24/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8713 - loss: 0.3733 - val_accuracy: 0.8781 - val_loss: 0.3467 - learning_rate: 5.0000e-04
# Epoch 25/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8718 - loss: 0.3756 - val_accuracy: 0.8838 - val_loss: 0.3460 - learning_rate: 5.0000e-04
# Epoch 26/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8722 - loss: 0.3683 - val_accuracy: 0.8838 - val_loss: 0.3456 - learning_rate: 5.0000e-04
# Epoch 27/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8758 - loss: 0.3641 - val_accuracy: 0.8808 - val_loss: 0.3467 - learning_rate: 5.0000e-04
# Epoch 28/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8779 - loss: 0.3599 - val_accuracy: 0.8817 - val_loss: 0.3457 - learning_rate: 5.0000e-04
# Epoch 29/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8745 - loss: 0.3697 - val_accuracy: 0.8818 - val_loss: 0.3466 - learning_rate: 5.0000e-04
# Epoch 30/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8764 - loss: 0.3644 - val_accuracy: 0.8822 - val_loss: 0.3465 - learning_rate: 5.0000e-04
# Epoch 31/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8734 - loss: 0.3677 - val_accuracy: 0.8806 - val_loss: 0.3460 - learning_rate: 5.0000e-04
# Epoch 32/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8756 - loss: 0.3674 - val_accuracy: 0.8825 - val_loss: 0.3444 - learning_rate: 2.5000e-04
# Epoch 33/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8780 - loss: 0.3601 - val_accuracy: 0.8812 - val_loss: 0.3448 - learning_rate: 2.5000e-04
# Epoch 34/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8754 - loss: 0.3593 - val_accuracy: 0.8822 - val_loss: 0.3412 - learning_rate: 2.5000e-04
# Epoch 35/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8808 - loss: 0.3454 - val_accuracy: 0.8821 - val_loss: 0.3402 - learning_rate: 2.5000e-04
# Epoch 36/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8796 - loss: 0.3493 - val_accuracy: 0.8832 - val_loss: 0.3414 - learning_rate: 2.5000e-04
# Epoch 37/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8819 - loss: 0.3487 - val_accuracy: 0.8838 - val_loss: 0.3408 - learning_rate: 2.5000e-04
# Epoch 38/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8778 - loss: 0.3546 - val_accuracy: 0.8839 - val_loss: 0.3404 - learning_rate: 2.5000e-04
# Epoch 39/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8791 - loss: 0.3470 - val_accuracy: 0.8823 - val_loss: 0.3403 - learning_rate: 2.5000e-04
# Epoch 40/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8790 - loss: 0.3555 - val_accuracy: 0.8824 - val_loss: 0.3415 - learning_rate: 2.5000e-04
# Epoch 41/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8764 - loss: 0.3543 - val_accuracy: 0.8833 - val_loss: 0.3395 - learning_rate: 1.2500e-04
# Epoch 42/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8815 - loss: 0.3392 - val_accuracy: 0.8829 - val_loss: 0.3391 - learning_rate: 1.2500e-04
# Epoch 43/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8806 - loss: 0.3467 - val_accuracy: 0.8830 - val_loss: 0.3392 - learning_rate: 1.2500e-04
# Epoch 44/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8845 - loss: 0.3360 - val_accuracy: 0.8838 - val_loss: 0.3390 - learning_rate: 1.2500e-04
# Epoch 45/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8804 - loss: 0.3403 - val_accuracy: 0.8835 - val_loss: 0.3389 - learning_rate: 1.2500e-04
# Epoch 46/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8791 - loss: 0.3470 - val_accuracy: 0.8839 - val_loss: 0.3380 - learning_rate: 1.2500e-04
# Epoch 47/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8776 - loss: 0.3481 - val_accuracy: 0.8849 - val_loss: 0.3382 - learning_rate: 1.2500e-04
# Epoch 48/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8810 - loss: 0.3453 - val_accuracy: 0.8839 - val_loss: 0.3385 - learning_rate: 1.2500e-04
# Epoch 49/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8841 - loss: 0.3422 - val_accuracy: 0.8846 - val_loss: 0.3383 - learning_rate: 1.2500e-04
# Epoch 50/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8798 - loss: 0.3458 - val_accuracy: 0.8833 - val_loss: 0.3386 - learning_rate: 1.2500e-04
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 1 - Accuracy : 0.8839
# Meilleur modèle mis à jour (Fold 1, Accuracy: 0.8839)
# Epoch 1/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7055 - loss: 0.9582 - val_accuracy: 0.8723 - val_loss: 0.4935 - learning_rate: 0.0010
# Epoch 2/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8586 - loss: 0.5346 - val_accuracy: 0.8747 - val_loss: 0.4424 - learning_rate: 0.0010
# Epoch 3/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8672 - loss: 0.4741 - val_accuracy: 0.8800 - val_loss: 0.4077 - learning_rate: 0.0010
# Epoch 4/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8671 - loss: 0.4477 - val_accuracy: 0.8773 - val_loss: 0.3872 - learning_rate: 0.0010
# Epoch 5/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8693 - loss: 0.4203 - val_accuracy: 0.8779 - val_loss: 0.3770 - learning_rate: 0.0010
# Epoch 6/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8725 - loss: 0.4031 - val_accuracy: 0.8781 - val_loss: 0.3712 - learning_rate: 0.0010
# Epoch 7/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8695 - loss: 0.4026 - val_accuracy: 0.8772 - val_loss: 0.3672 - learning_rate: 0.0010
# Epoch 8/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8751 - loss: 0.3881 - val_accuracy: 0.8776 - val_loss: 0.3644 - learning_rate: 0.0010
# Epoch 9/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8707 - loss: 0.3868 - val_accuracy: 0.8792 - val_loss: 0.3668 - learning_rate: 0.0010
# Epoch 10/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8736 - loss: 0.3891 - val_accuracy: 0.8775 - val_loss: 0.3611 - learning_rate: 0.0010
# Epoch 11/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8707 - loss: 0.3915 - val_accuracy: 0.8758 - val_loss: 0.3704 - learning_rate: 0.0010
# Epoch 12/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8700 - loss: 0.3890 - val_accuracy: 0.8812 - val_loss: 0.3627 - learning_rate: 0.0010
# Epoch 13/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8692 - loss: 0.3874 - val_accuracy: 0.8791 - val_loss: 0.3660 - learning_rate: 0.0010
# Epoch 14/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8668 - loss: 0.3937 - val_accuracy: 0.8805 - val_loss: 0.3626 - learning_rate: 0.0010
# Epoch 15/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8711 - loss: 0.3898 - val_accuracy: 0.8790 - val_loss: 0.3618 - learning_rate: 0.0010
# Epoch 16/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8746 - loss: 0.3816 - val_accuracy: 0.8805 - val_loss: 0.3552 - learning_rate: 5.0000e-04
# Epoch 17/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8730 - loss: 0.3758 - val_accuracy: 0.8818 - val_loss: 0.3562 - learning_rate: 5.0000e-04
# Epoch 18/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8773 - loss: 0.3754 - val_accuracy: 0.8803 - val_loss: 0.3517 - learning_rate: 5.0000e-04
# Epoch 19/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8776 - loss: 0.3668 - val_accuracy: 0.8795 - val_loss: 0.3531 - learning_rate: 5.0000e-04
# Epoch 20/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8754 - loss: 0.3680 - val_accuracy: 0.8821 - val_loss: 0.3496 - learning_rate: 5.0000e-04
# Epoch 21/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8730 - loss: 0.3721 - val_accuracy: 0.8786 - val_loss: 0.3540 - learning_rate: 5.0000e-04
# Epoch 22/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8720 - loss: 0.3717 - val_accuracy: 0.8812 - val_loss: 0.3495 - learning_rate: 5.0000e-04
# Epoch 23/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8738 - loss: 0.3695 - val_accuracy: 0.8807 - val_loss: 0.3510 - learning_rate: 5.0000e-04
# Epoch 24/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8779 - loss: 0.3553 - val_accuracy: 0.8800 - val_loss: 0.3503 - learning_rate: 5.0000e-04
# Epoch 25/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8725 - loss: 0.3700 - val_accuracy: 0.8775 - val_loss: 0.3526 - learning_rate: 5.0000e-04
# Epoch 26/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8740 - loss: 0.3705 - val_accuracy: 0.8795 - val_loss: 0.3517 - learning_rate: 2.5000e-04
# Epoch 27/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8749 - loss: 0.3638 - val_accuracy: 0.8808 - val_loss: 0.3477 - learning_rate: 2.5000e-04
# Epoch 28/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8784 - loss: 0.3562 - val_accuracy: 0.8801 - val_loss: 0.3467 - learning_rate: 2.5000e-04
# Epoch 29/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8781 - loss: 0.3517 - val_accuracy: 0.8796 - val_loss: 0.3470 - learning_rate: 2.5000e-04
# Epoch 30/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8797 - loss: 0.3557 - val_accuracy: 0.8823 - val_loss: 0.3467 - learning_rate: 2.5000e-04
# Epoch 31/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8808 - loss: 0.3532 - val_accuracy: 0.8817 - val_loss: 0.3446 - learning_rate: 2.5000e-04
# Epoch 32/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8784 - loss: 0.3558 - val_accuracy: 0.8802 - val_loss: 0.3452 - learning_rate: 2.5000e-04
# Epoch 33/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8768 - loss: 0.3600 - val_accuracy: 0.8819 - val_loss: 0.3456 - learning_rate: 2.5000e-04
# Epoch 34/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8782 - loss: 0.3585 - val_accuracy: 0.8812 - val_loss: 0.3477 - learning_rate: 2.5000e-04
# Epoch 35/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8784 - loss: 0.3486 - val_accuracy: 0.8806 - val_loss: 0.3437 - learning_rate: 2.5000e-04
# Epoch 36/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8756 - loss: 0.3563 - val_accuracy: 0.8800 - val_loss: 0.3469 - learning_rate: 2.5000e-04
# Epoch 37/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8781 - loss: 0.3451 - val_accuracy: 0.8811 - val_loss: 0.3449 - learning_rate: 2.5000e-04
# Epoch 38/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8828 - loss: 0.3409 - val_accuracy: 0.8803 - val_loss: 0.3459 - learning_rate: 2.5000e-04
# Epoch 39/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8797 - loss: 0.3496 - val_accuracy: 0.8814 - val_loss: 0.3438 - learning_rate: 2.5000e-04
# Epoch 40/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8810 - loss: 0.3481 - val_accuracy: 0.8808 - val_loss: 0.3449 - learning_rate: 2.5000e-04
# Epoch 41/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8825 - loss: 0.3439 - val_accuracy: 0.8808 - val_loss: 0.3435 - learning_rate: 1.2500e-04
# Epoch 42/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.8803 - loss: 0.3506 - val_accuracy: 0.8792 - val_loss: 0.3440 - learning_rate: 1.2500e-04
# Epoch 43/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8792 - loss: 0.3492 - val_accuracy: 0.8805 - val_loss: 0.3431 - learning_rate: 1.2500e-04
# Epoch 44/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8804 - loss: 0.3476 - val_accuracy: 0.8805 - val_loss: 0.3447 - learning_rate: 1.2500e-04
# Epoch 45/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8818 - loss: 0.3439 - val_accuracy: 0.8813 - val_loss: 0.3431 - learning_rate: 1.2500e-04
# Epoch 46/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8785 - loss: 0.3470 - val_accuracy: 0.8812 - val_loss: 0.3448 - learning_rate: 1.2500e-04
# Epoch 47/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8828 - loss: 0.3381 - val_accuracy: 0.8816 - val_loss: 0.3445 - learning_rate: 1.2500e-04
# Epoch 48/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8832 - loss: 0.3415 - val_accuracy: 0.8800 - val_loss: 0.3435 - learning_rate: 1.2500e-04
# Epoch 49/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8827 - loss: 0.3381 - val_accuracy: 0.8794 - val_loss: 0.3435 - learning_rate: 6.2500e-05
# Epoch 50/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8839 - loss: 0.3334 - val_accuracy: 0.8806 - val_loss: 0.3425 - learning_rate: 6.2500e-05
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold 2 - Accuracy : 0.8806
# Epoch 1/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.7845 - loss: 0.7722 - val_accuracy: 0.8729 - val_loss: 0.4815 - learning_rate: 0.0010
# Epoch 2/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8580 - loss: 0.5244 - val_accuracy: 0.8735 - val_loss: 0.4386 - learning_rate: 0.0010
# Epoch 3/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8633 - loss: 0.4760 - val_accuracy: 0.8745 - val_loss: 0.4065 - learning_rate: 0.0010
# Epoch 4/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8666 - loss: 0.4489 - val_accuracy: 0.8763 - val_loss: 0.3844 - learning_rate: 0.0010
# Epoch 5/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8686 - loss: 0.4194 - val_accuracy: 0.8710 - val_loss: 0.3827 - learning_rate: 0.0010
# Epoch 6/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8721 - loss: 0.4041 - val_accuracy: 0.8745 - val_loss: 0.3696 - learning_rate: 0.0010
# Epoch 7/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8662 - loss: 0.4080 - val_accuracy: 0.8764 - val_loss: 0.3638 - learning_rate: 0.0010
# Epoch 8/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8661 - loss: 0.4006 - val_accuracy: 0.8774 - val_loss: 0.3649 - learning_rate: 0.0010
# Epoch 9/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8712 - loss: 0.3962 - val_accuracy: 0.8768 - val_loss: 0.3627 - learning_rate: 0.0010
# Epoch 10/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8738 - loss: 0.3907 - val_accuracy: 0.8758 - val_loss: 0.3583 - learning_rate: 0.0010
# Epoch 11/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8699 - loss: 0.3911 - val_accuracy: 0.8756 - val_loss: 0.3594 - learning_rate: 0.0010
# Epoch 12/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8689 - loss: 0.3924 - val_accuracy: 0.8739 - val_loss: 0.3632 - learning_rate: 0.0010
# Epoch 13/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8713 - loss: 0.3897 - val_accuracy: 0.8756 - val_loss: 0.3582 - learning_rate: 0.0010
# Epoch 14/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8723 - loss: 0.3875 - val_accuracy: 0.8801 - val_loss: 0.3590 - learning_rate: 0.0010
# Epoch 15/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8709 - loss: 0.3909 - val_accuracy: 0.8790 - val_loss: 0.3571 - learning_rate: 0.0010
# Epoch 16/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8738 - loss: 0.3859 - val_accuracy: 0.8734 - val_loss: 0.3635 - learning_rate: 0.0010
# Epoch 17/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8698 - loss: 0.3950 - val_accuracy: 0.8770 - val_loss: 0.3613 - learning_rate: 0.0010
# Epoch 18/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8682 - loss: 0.3870 - val_accuracy: 0.8742 - val_loss: 0.3662 - learning_rate: 0.0010
# Epoch 19/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8750 - loss: 0.3839 - val_accuracy: 0.8765 - val_loss: 0.3618 - learning_rate: 0.0010
# Epoch 20/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8676 - loss: 0.3973 - val_accuracy: 0.8762 - val_loss: 0.3590 - learning_rate: 0.0010
# Epoch 21/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8731 - loss: 0.3795 - val_accuracy: 0.8778 - val_loss: 0.3559 - learning_rate: 5.0000e-04
# Epoch 22/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8744 - loss: 0.3781 - val_accuracy: 0.8803 - val_loss: 0.3509 - learning_rate: 5.0000e-04
# Epoch 23/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 7s 7ms/step - accuracy: 0.8757 - loss: 0.3738 - val_accuracy: 0.8784 - val_loss: 0.3514 - learning_rate: 5.0000e-04
# Epoch 24/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - accuracy: 0.8748 - loss: 0.3661 - val_accuracy: 0.8774 - val_loss: 0.3494 - learning_rate: 5.0000e-04
# Epoch 25/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8754 - loss: 0.3697 - val_accuracy: 0.8800 - val_loss: 0.3476 - learning_rate: 5.0000e-04
# Epoch 26/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8787 - loss: 0.3712 - val_accuracy: 0.8762 - val_loss: 0.3503 - learning_rate: 5.0000e-04
# Epoch 27/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8772 - loss: 0.3635 - val_accuracy: 0.8768 - val_loss: 0.3472 - learning_rate: 5.0000e-04
# Epoch 28/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8786 - loss: 0.3646 - val_accuracy: 0.8792 - val_loss: 0.3488 - learning_rate: 5.0000e-04
# Epoch 29/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8747 - loss: 0.3662 - val_accuracy: 0.8752 - val_loss: 0.3511 - learning_rate: 5.0000e-04
# Epoch 30/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8762 - loss: 0.3660 - val_accuracy: 0.8806 - val_loss: 0.3472 - learning_rate: 5.0000e-04
# Epoch 31/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8770 - loss: 0.3669 - val_accuracy: 0.8763 - val_loss: 0.3493 - learning_rate: 5.0000e-04
# Epoch 32/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8752 - loss: 0.3688 - val_accuracy: 0.8772 - val_loss: 0.3471 - learning_rate: 5.0000e-04
# Epoch 33/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8779 - loss: 0.3636 - val_accuracy: 0.8791 - val_loss: 0.3495 - learning_rate: 5.0000e-04
# Epoch 34/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8770 - loss: 0.3628 - val_accuracy: 0.8780 - val_loss: 0.3499 - learning_rate: 5.0000e-04
# Epoch 35/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8745 - loss: 0.3668 - val_accuracy: 0.8736 - val_loss: 0.3531 - learning_rate: 5.0000e-04
# Epoch 36/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8776 - loss: 0.3669 - val_accuracy: 0.8795 - val_loss: 0.3495 - learning_rate: 5.0000e-04
# Epoch 37/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8771 - loss: 0.3697 - val_accuracy: 0.8798 - val_loss: 0.3496 - learning_rate: 5.0000e-04
# Epoch 38/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8789 - loss: 0.3541 - val_accuracy: 0.8787 - val_loss: 0.3481 - learning_rate: 2.5000e-04
# Epoch 39/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8756 - loss: 0.3599 - val_accuracy: 0.8791 - val_loss: 0.3471 - learning_rate: 2.5000e-04
# Epoch 40/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8785 - loss: 0.3511 - val_accuracy: 0.8798 - val_loss: 0.3458 - learning_rate: 2.5000e-04
# Epoch 41/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8799 - loss: 0.3500 - val_accuracy: 0.8791 - val_loss: 0.3452 - learning_rate: 2.5000e-04
# Epoch 42/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8747 - loss: 0.3566 - val_accuracy: 0.8807 - val_loss: 0.3456 - learning_rate: 2.5000e-04
# Epoch 43/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8826 - loss: 0.3504 - val_accuracy: 0.8781 - val_loss: 0.3458 - learning_rate: 2.5000e-04
# Epoch 44/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8776 - loss: 0.3578 - val_accuracy: 0.8794 - val_loss: 0.3444 - learning_rate: 2.5000e-04
# Epoch 45/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8806 - loss: 0.3497 - val_accuracy: 0.8787 - val_loss: 0.3452 - learning_rate: 2.5000e-04
# Epoch 46/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8829 - loss: 0.3451 - val_accuracy: 0.8770 - val_loss: 0.3478 - learning_rate: 2.5000e-04
# Epoch 47/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8811 - loss: 0.3486 - val_accuracy: 0.8796 - val_loss: 0.3444 - learning_rate: 2.5000e-04
# Epoch 48/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8811 - loss: 0.3455 - val_accuracy: 0.8773 - val_loss: 0.3439 - learning_rate: 2.5000e-04
# Epoch 49/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8825 - loss: 0.3428 - val_accuracy: 0.8791 - val_loss: 0.3446 - learning_rate: 2.5000e-04
# Epoch 50/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8837 - loss: 0.3496 - val_accuracy: 0.8800 - val_loss: 0.3442 - learning_rate: 2.5000e-04
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Fold 3 - Accuracy : 0.8773
# Epoch 1/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.7709 - loss: 0.7902 - val_accuracy: 0.8744 - val_loss: 0.4850 - learning_rate: 0.0010
# Epoch 2/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8549 - loss: 0.5405 - val_accuracy: 0.8762 - val_loss: 0.4390 - learning_rate: 0.0010
# Epoch 3/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8620 - loss: 0.4779 - val_accuracy: 0.8770 - val_loss: 0.4040 - learning_rate: 0.0010
# Epoch 4/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8634 - loss: 0.4438 - val_accuracy: 0.8769 - val_loss: 0.3840 - learning_rate: 0.0010
# Epoch 5/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8705 - loss: 0.4141 - val_accuracy: 0.8797 - val_loss: 0.3699 - learning_rate: 0.0010
# Epoch 6/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8655 - loss: 0.4146 - val_accuracy: 0.8791 - val_loss: 0.3632 - learning_rate: 0.0010
# Epoch 7/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8666 - loss: 0.4058 - val_accuracy: 0.8811 - val_loss: 0.3631 - learning_rate: 0.0010
# Epoch 8/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8674 - loss: 0.3947 - val_accuracy: 0.8801 - val_loss: 0.3609 - learning_rate: 0.0010
# Epoch 9/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8688 - loss: 0.3959 - val_accuracy: 0.8813 - val_loss: 0.3532 - learning_rate: 0.0010
# Epoch 10/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8712 - loss: 0.3947 - val_accuracy: 0.8787 - val_loss: 0.3582 - learning_rate: 0.0010
# Epoch 11/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8677 - loss: 0.3974 - val_accuracy: 0.8831 - val_loss: 0.3607 - learning_rate: 0.0010
# Epoch 12/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8714 - loss: 0.3885 - val_accuracy: 0.8778 - val_loss: 0.3581 - learning_rate: 0.0010
# Epoch 13/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8705 - loss: 0.3884 - val_accuracy: 0.8795 - val_loss: 0.3558 - learning_rate: 0.0010
# Epoch 14/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8665 - loss: 0.3906 - val_accuracy: 0.8786 - val_loss: 0.3573 - learning_rate: 0.0010
# Epoch 15/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8709 - loss: 0.3843 - val_accuracy: 0.8802 - val_loss: 0.3471 - learning_rate: 5.0000e-04
# Epoch 16/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8740 - loss: 0.3808 - val_accuracy: 0.8815 - val_loss: 0.3475 - learning_rate: 5.0000e-04
# Epoch 17/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8738 - loss: 0.3804 - val_accuracy: 0.8823 - val_loss: 0.3460 - learning_rate: 5.0000e-04
# Epoch 18/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8708 - loss: 0.3776 - val_accuracy: 0.8819 - val_loss: 0.3448 - learning_rate: 5.0000e-04
# Epoch 19/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8763 - loss: 0.3691 - val_accuracy: 0.8807 - val_loss: 0.3445 - learning_rate: 5.0000e-04
# Epoch 20/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8736 - loss: 0.3723 - val_accuracy: 0.8812 - val_loss: 0.3447 - learning_rate: 5.0000e-04
# Epoch 21/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8730 - loss: 0.3672 - val_accuracy: 0.8845 - val_loss: 0.3421 - learning_rate: 5.0000e-04
# Epoch 22/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8736 - loss: 0.3732 - val_accuracy: 0.8817 - val_loss: 0.3413 - learning_rate: 5.0000e-04
# Epoch 23/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8758 - loss: 0.3694 - val_accuracy: 0.8818 - val_loss: 0.3410 - learning_rate: 5.0000e-04
# Epoch 24/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8756 - loss: 0.3697 - val_accuracy: 0.8822 - val_loss: 0.3418 - learning_rate: 5.0000e-04
# Epoch 25/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8761 - loss: 0.3627 - val_accuracy: 0.8833 - val_loss: 0.3452 - learning_rate: 5.0000e-04
# Epoch 26/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8729 - loss: 0.3667 - val_accuracy: 0.8828 - val_loss: 0.3407 - learning_rate: 5.0000e-04
# Epoch 27/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8789 - loss: 0.3621 - val_accuracy: 0.8831 - val_loss: 0.3408 - learning_rate: 5.0000e-04
# Epoch 28/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8761 - loss: 0.3663 - val_accuracy: 0.8844 - val_loss: 0.3439 - learning_rate: 5.0000e-04
# Epoch 29/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8732 - loss: 0.3720 - val_accuracy: 0.8834 - val_loss: 0.3433 - learning_rate: 5.0000e-04
# Epoch 30/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8803 - loss: 0.3624 - val_accuracy: 0.8826 - val_loss: 0.3430 - learning_rate: 5.0000e-04
# Epoch 31/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8784 - loss: 0.3647 - val_accuracy: 0.8823 - val_loss: 0.3432 - learning_rate: 5.0000e-04
# Epoch 32/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8801 - loss: 0.3564 - val_accuracy: 0.8819 - val_loss: 0.3408 - learning_rate: 2.5000e-04
# Epoch 33/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8774 - loss: 0.3559 - val_accuracy: 0.8837 - val_loss: 0.3374 - learning_rate: 2.5000e-04
# Epoch 34/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8756 - loss: 0.3539 - val_accuracy: 0.8828 - val_loss: 0.3367 - learning_rate: 2.5000e-04
# Epoch 35/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8794 - loss: 0.3533 - val_accuracy: 0.8812 - val_loss: 0.3374 - learning_rate: 2.5000e-04
# Epoch 36/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8805 - loss: 0.3519 - val_accuracy: 0.8829 - val_loss: 0.3372 - learning_rate: 2.5000e-04
# Epoch 37/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8779 - loss: 0.3510 - val_accuracy: 0.8825 - val_loss: 0.3382 - learning_rate: 2.5000e-04
# Epoch 38/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8797 - loss: 0.3558 - val_accuracy: 0.8824 - val_loss: 0.3384 - learning_rate: 2.5000e-04
# Epoch 39/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8779 - loss: 0.3518 - val_accuracy: 0.8820 - val_loss: 0.3371 - learning_rate: 2.5000e-04
# Epoch 40/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8795 - loss: 0.3523 - val_accuracy: 0.8834 - val_loss: 0.3347 - learning_rate: 1.2500e-04
# Epoch 41/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8795 - loss: 0.3486 - val_accuracy: 0.8836 - val_loss: 0.3347 - learning_rate: 1.2500e-04
# Epoch 42/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8783 - loss: 0.3532 - val_accuracy: 0.8831 - val_loss: 0.3332 - learning_rate: 1.2500e-04
# Epoch 43/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8823 - loss: 0.3398 - val_accuracy: 0.8824 - val_loss: 0.3346 - learning_rate: 1.2500e-04
# Epoch 44/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8774 - loss: 0.3527 - val_accuracy: 0.8829 - val_loss: 0.3340 - learning_rate: 1.2500e-04
# Epoch 45/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8833 - loss: 0.3416 - val_accuracy: 0.8835 - val_loss: 0.3332 - learning_rate: 1.2500e-04
# Epoch 46/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8832 - loss: 0.3386 - val_accuracy: 0.8853 - val_loss: 0.3334 - learning_rate: 1.2500e-04
# Epoch 47/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8832 - loss: 0.3436 - val_accuracy: 0.8831 - val_loss: 0.3337 - learning_rate: 1.2500e-04
# Epoch 48/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8806 - loss: 0.3453 - val_accuracy: 0.8845 - val_loss: 0.3329 - learning_rate: 6.2500e-05
# Epoch 49/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8845 - loss: 0.3368 - val_accuracy: 0.8850 - val_loss: 0.3325 - learning_rate: 6.2500e-05
# Epoch 50/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8826 - loss: 0.3403 - val_accuracy: 0.8841 - val_loss: 0.3325 - learning_rate: 6.2500e-05
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 4 - Accuracy : 0.8841
# Meilleur modèle mis à jour (Fold 4, Accuracy: 0.8841)
# Epoch 1/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.7783 - loss: 0.7732 - val_accuracy: 0.8839 - val_loss: 0.4691 - learning_rate: 0.0010
# Epoch 2/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8557 - loss: 0.5420 - val_accuracy: 0.8844 - val_loss: 0.4218 - learning_rate: 0.0010
# Epoch 3/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8611 - loss: 0.4843 - val_accuracy: 0.8888 - val_loss: 0.3832 - learning_rate: 0.0010
# Epoch 4/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8639 - loss: 0.4524 - val_accuracy: 0.8884 - val_loss: 0.3636 - learning_rate: 0.0010
# Epoch 5/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8647 - loss: 0.4280 - val_accuracy: 0.8867 - val_loss: 0.3524 - learning_rate: 0.0010
# Epoch 6/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8652 - loss: 0.4243 - val_accuracy: 0.8850 - val_loss: 0.3458 - learning_rate: 0.0010
# Epoch 7/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - accuracy: 0.8669 - loss: 0.4076 - val_accuracy: 0.8878 - val_loss: 0.3430 - learning_rate: 0.0010
# Epoch 8/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8675 - loss: 0.4025 - val_accuracy: 0.8901 - val_loss: 0.3388 - learning_rate: 0.0010
# Epoch 9/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8669 - loss: 0.3995 - val_accuracy: 0.8884 - val_loss: 0.3396 - learning_rate: 0.0010
# Epoch 10/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8696 - loss: 0.3917 - val_accuracy: 0.8837 - val_loss: 0.3419 - learning_rate: 0.0010
# Epoch 11/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8696 - loss: 0.3938 - val_accuracy: 0.8880 - val_loss: 0.3380 - learning_rate: 0.0010
# Epoch 12/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8674 - loss: 0.3956 - val_accuracy: 0.8879 - val_loss: 0.3386 - learning_rate: 0.0010
# Epoch 13/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8684 - loss: 0.4005 - val_accuracy: 0.8874 - val_loss: 0.3388 - learning_rate: 0.0010
# Epoch 14/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8666 - loss: 0.3980 - val_accuracy: 0.8904 - val_loss: 0.3319 - learning_rate: 0.0010
# Epoch 15/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8708 - loss: 0.3908 - val_accuracy: 0.8866 - val_loss: 0.3414 - learning_rate: 0.0010
# Epoch 16/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8719 - loss: 0.3842 - val_accuracy: 0.8878 - val_loss: 0.3393 - learning_rate: 0.0010
# Epoch 17/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8710 - loss: 0.3887 - val_accuracy: 0.8894 - val_loss: 0.3309 - learning_rate: 0.0010
# Epoch 18/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8742 - loss: 0.3852 - val_accuracy: 0.8868 - val_loss: 0.3388 - learning_rate: 0.0010
# Epoch 19/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8683 - loss: 0.3892 - val_accuracy: 0.8880 - val_loss: 0.3366 - learning_rate: 0.0010
# Epoch 20/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8670 - loss: 0.3968 - val_accuracy: 0.8885 - val_loss: 0.3340 - learning_rate: 0.0010
# Epoch 21/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8664 - loss: 0.3945 - val_accuracy: 0.8872 - val_loss: 0.3372 - learning_rate: 0.0010
# Epoch 22/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8683 - loss: 0.3970 - val_accuracy: 0.8860 - val_loss: 0.3373 - learning_rate: 0.0010
# Epoch 23/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8698 - loss: 0.3840 - val_accuracy: 0.8912 - val_loss: 0.3286 - learning_rate: 5.0000e-04
# Epoch 24/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8732 - loss: 0.3736 - val_accuracy: 0.8901 - val_loss: 0.3266 - learning_rate: 5.0000e-04
# Epoch 25/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8699 - loss: 0.3865 - val_accuracy: 0.8895 - val_loss: 0.3263 - learning_rate: 5.0000e-04
# Epoch 26/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8742 - loss: 0.3714 - val_accuracy: 0.8906 - val_loss: 0.3236 - learning_rate: 5.0000e-04
# Epoch 27/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.8734 - loss: 0.3727 - val_accuracy: 0.8921 - val_loss: 0.3221 - learning_rate: 5.0000e-04
# Epoch 28/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8735 - loss: 0.3711 - val_accuracy: 0.8891 - val_loss: 0.3242 - learning_rate: 5.0000e-04
# Epoch 29/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8731 - loss: 0.3684 - val_accuracy: 0.8897 - val_loss: 0.3231 - learning_rate: 5.0000e-04
# Epoch 30/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8689 - loss: 0.3778 - val_accuracy: 0.8862 - val_loss: 0.3255 - learning_rate: 5.0000e-04
# Epoch 31/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8700 - loss: 0.3781 - val_accuracy: 0.8905 - val_loss: 0.3243 - learning_rate: 5.0000e-04
# Epoch 32/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8732 - loss: 0.3713 - val_accuracy: 0.8899 - val_loss: 0.3245 - learning_rate: 5.0000e-04
# Epoch 33/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8731 - loss: 0.3741 - val_accuracy: 0.8901 - val_loss: 0.3210 - learning_rate: 2.5000e-04
# Epoch 34/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8741 - loss: 0.3658 - val_accuracy: 0.8908 - val_loss: 0.3218 - learning_rate: 2.5000e-04
# Epoch 35/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8743 - loss: 0.3639 - val_accuracy: 0.8921 - val_loss: 0.3198 - learning_rate: 2.5000e-04
# Epoch 36/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8755 - loss: 0.3586 - val_accuracy: 0.8916 - val_loss: 0.3197 - learning_rate: 2.5000e-04
# Epoch 37/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8786 - loss: 0.3547 - val_accuracy: 0.8906 - val_loss: 0.3190 - learning_rate: 2.5000e-04
# Epoch 38/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8771 - loss: 0.3561 - val_accuracy: 0.8901 - val_loss: 0.3189 - learning_rate: 2.5000e-04
# Epoch 39/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8796 - loss: 0.3519 - val_accuracy: 0.8889 - val_loss: 0.3194 - learning_rate: 2.5000e-04
# Epoch 40/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8771 - loss: 0.3530 - val_accuracy: 0.8894 - val_loss: 0.3182 - learning_rate: 2.5000e-04
# Epoch 41/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8781 - loss: 0.3530 - val_accuracy: 0.8902 - val_loss: 0.3182 - learning_rate: 2.5000e-04
# Epoch 42/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8747 - loss: 0.3576 - val_accuracy: 0.8918 - val_loss: 0.3176 - learning_rate: 2.5000e-04
# Epoch 43/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8773 - loss: 0.3582 - val_accuracy: 0.8910 - val_loss: 0.3196 - learning_rate: 2.5000e-04
# Epoch 44/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8773 - loss: 0.3565 - val_accuracy: 0.8899 - val_loss: 0.3189 - learning_rate: 2.5000e-04
# Epoch 45/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8804 - loss: 0.3529 - val_accuracy: 0.8913 - val_loss: 0.3179 - learning_rate: 2.5000e-04
# Epoch 46/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8791 - loss: 0.3560 - val_accuracy: 0.8917 - val_loss: 0.3165 - learning_rate: 2.5000e-04
# Epoch 47/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8769 - loss: 0.3543 - val_accuracy: 0.8923 - val_loss: 0.3183 - learning_rate: 2.5000e-04
# Epoch 48/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8805 - loss: 0.3486 - val_accuracy: 0.8889 - val_loss: 0.3208 - learning_rate: 2.5000e-04
# Epoch 49/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8776 - loss: 0.3561 - val_accuracy: 0.8906 - val_loss: 0.3188 - learning_rate: 2.5000e-04
# Epoch 50/50
# 1022/1022 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.8791 - loss: 0.3492 - val_accuracy: 0.8915 - val_loss: 0.3175 - learning_rate: 2.5000e-04
# 256/256 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Fold 5 - Accuracy : 0.8917
# Meilleur modèle mis à jour (Fold 5, Accuracy: 0.8917)
# Précision moyenne : 0.8835
# Écart type de la précision : 0.0048
# Meilleur modèle sauvegardé : Fold 5 avec une précision de 0.8917

# %%
# Import des données
competition_data = pd.read_csv('EEG_mouse_data_test.csv')
competition_data = competition_data.iloc[:, :25]

# Charger le meilleur modèle
best_model = load_model("best_fold_model.h5")

# Normaliser les données de test avec le même scaler
X_test_normalized = scaler.fit_transform(competition_data)

# Prédictions sur les données de test (probabilités)
y_pred_test = best_model.predict(X_test_normalized)

# Obtenir les classes prédites avec np.argmax
y_pred_classes = np.argmax(y_pred_test, axis=1)

# Créer un mappage des indices de classe vers des lettres
class_mapping = {0: 'n', 1: 'r', 2: 'w'}

# Appliquer le mappage aux prédictions
y_pred_classes_mapped = np.array([class_mapping[class_idx] for class_idx in y_pred_classes])

# Sauvegarder les classes prédites avec lettres (n, r, w)
np.save("TestPred_Competition_PiemontesiTrueb.npy", y_pred_classes_mapped)

# Convertir les prédictions en pandas Series pour utiliser value_counts
y_pred_test_series = pd.Series(y_pred_classes_mapped)

# Créer un barplot des occurrences des classes
plt.figure(figsize=(10, 6))
y_pred_test_series.value_counts().plot(kind='bar', color='darkgreen')

# Ajouter des labels et un titre
plt.title('Total Occurrences per Predicted Class')
plt.xlabel('Predicted Class')
plt.ylabel('Count')

# Rotation des labels sur l'axe x
plt.xticks(rotation=0)

# Mise en forme du graphique
plt.tight_layout()
plt.show()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 2504/2504 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step
